# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 39 not upgraded.
# Need to get 9,604 kB of archives.
# After this operation, 29.5 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 fonts-nanum all 20170925-1 [9,604 kB]
# Fetched 9,604 kB in 0s (23.4 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.rc('font', family='NanumBarunGothic')

ncsoft_df = pd.read_csv('/content/gdrive/MyDrive/bigdata analytics/week3/엔씨소프트/data.csv')

# %% [markdown]
# ### "소문에 사서 뉴스에 팔라"
#
# <br>
#
# ### 가설1: 게임을 출시한 주에 해당 게임에 대한 검색량과 거래량은 비례할 것이다
#
# ### 가설2: 선반영으로 인해서 그 전에 이미 주가가 올랐기 때문에 출시날 주가가 하락할 것이다.

# %% [markdown]
# ### 2017년 6월 (리니지 M 출시 - 2017년 6월 21일)

# %%
fig = plt.figure(figsize=(30, 9))

date = ncsoft_df.iloc[45:60]['Date']
lineage_m = ncsoft_df.iloc[45:60]['LineageM']
price = ncsoft_df.iloc[45:60]['Close']
volume = ncsoft_df.iloc[45:60]['Volume']

## 일별 리니지M 검색량 그래프 ##
plt.subplot(2, 2, 1)
plt.plot(date, lineage_m)

# 휴장일 표시
plt.plot(ncsoft_df.iloc[47:49]['Date'], ncsoft_df.iloc[47:49]['LineageM'], color='red')
plt.plot(ncsoft_df.iloc[54:56]['Date'], ncsoft_df.iloc[54:56]['LineageM'], color='red')
plt.legend(('개장','휴장'))

# 출시일 표시
plt.text(ncsoft_df.iloc[51]['Date'], ncsoft_df.iloc[51]['LineageM'], '리니지M 출시')
plt.plot(ncsoft_df.iloc[51]['Date'], ncsoft_df.iloc[51]['LineageM'], 'mX')

plt.title('리니지M 검색량')


## 일별 엔씨소프트 거래량 그래프 ##
plt.subplot(2, 2, 3)
plt.plot(date, volume)

# 휴장일 표시
plt.plot(ncsoft_df.iloc[47:49]['Date'], ncsoft_df.iloc[47:49]['Volume'], color='red')
plt.plot(ncsoft_df.iloc[54:56]['Date'], ncsoft_df.iloc[54:56]['Volume'], color='red')
plt.legend(('개장','휴장'))

# 출시일 표시
plt.text(ncsoft_df.iloc[51]['Date'], ncsoft_df.iloc[51]['Volume'], '리니지M 출시')
plt.plot(ncsoft_df.iloc[51]['Date'], ncsoft_df.iloc[51]['Volume'], 'mX')

plt.title('엔씨소프트 거래량')
# Out:
# Text(0.5, 1.0, '엔씨소프트 거래량')

# %%
plt.figure(figsize=(20, 6))

date = ncsoft_df.iloc[45:60]['Date']
price = ncsoft_df.iloc[45:60]['Close']

plt.plot(date, price)

# 휴장일 표시
plt.plot(ncsoft_df.iloc[47:49]['Date'], ncsoft_df.iloc[47:49]['Close'], color='red')
plt.plot(ncsoft_df.iloc[54:56]['Date'], ncsoft_df.iloc[54:56]['Close'], color='red')
plt.legend(('개장','휴장'))

# 출시일 표시
plt.text(ncsoft_df.iloc[51]['Date'], ncsoft_df.iloc[51]['Close'], '리니지M 출시')
plt.plot(ncsoft_df.iloc[51]['Date'], ncsoft_df.iloc[51]['Close'], 'mX')

plt.title('엔씨소프트 종가')
# Out:
# Text(0.5, 1.0, '엔씨소프트 종가')

# %% [markdown]
# ### 2019년 11월 (리니지 2M 출시 - 2019년 11월 27일)

# %%
fig = plt.figure(figsize=(30, 9))

date = ncsoft_df.iloc[934:948]['Date']
lineage_2m = ncsoft_df.iloc[934:948]['Lineage2M']
price = ncsoft_df.iloc[934:948]['Close']
volume = ncsoft_df.iloc[934:948]['Volume']

## 일별 리니지2M 검색량 그래프 ##
plt.subplot(2, 2, 1)
plt.plot(date, lineage_2m)

# 휴장일 표시
plt.plot(ncsoft_df.iloc[936:938]['Date'], ncsoft_df.iloc[936:938]['Lineage2M'], color='red')
plt.plot(ncsoft_df.iloc[943:945]['Date'], ncsoft_df.iloc[943:945]['Lineage2M'], color='red')
plt.legend(('개장','휴장'))

# 출시일 표시
plt.text(ncsoft_df.iloc[940]['Date'], ncsoft_df.iloc[940]['Lineage2M'], '리니지2M 출시')
plt.plot(ncsoft_df.iloc[940]['Date'], ncsoft_df.iloc[940]['Lineage2M'], 'mX')

plt.title('리니지2M 검색량')


## 일별 엔씨소프트 거래량 그래프 ##
plt.subplot(2, 2, 3)
plt.plot(date, volume)

# 휴장일 표시
plt.plot(ncsoft_df.iloc[936:938]['Date'], ncsoft_df.iloc[936:938]['Volume'], color='red')
plt.plot(ncsoft_df.iloc[943:945]['Date'], ncsoft_df.iloc[943:945]['Volume'], color='red')
plt.legend(('개장','휴장'))

# 출시일 표시
plt.text(ncsoft_df.iloc[940]['Date'], ncsoft_df.iloc[940]['Volume'], '리니지2M 출시')
plt.plot(ncsoft_df.iloc[940]['Date'], ncsoft_df.iloc[940]['Volume'], 'mX')

plt.title('엔씨소프트 거래량')
# Out:
# Text(0.5, 1.0, '엔씨소프트 거래량')

# %%
plt.figure(figsize=(20, 6))

date = ncsoft_df.iloc[934:948]['Date']
price = ncsoft_df.iloc[934:948]['Close']

plt.plot(date, price)

# 휴장일 표시
plt.plot(ncsoft_df.iloc[936:938]['Date'], ncsoft_df.iloc[936:938]['Close'], color='red')
plt.plot(ncsoft_df.iloc[943:945]['Date'], ncsoft_df.iloc[943:945]['Close'], color='red')
plt.legend(('개장','휴장'))

# 출시일 표시
plt.text(ncsoft_df.iloc[940]['Date'], ncsoft_df.iloc[940]['Close'], '리니지2M 출시')
plt.plot(ncsoft_df.iloc[940]['Date'], ncsoft_df.iloc[940]['Close'], 'mX')

plt.title('엔씨소프트 종가')
# Out:
# Text(0.5, 1.0, '엔씨소프트 종가')

# %% [markdown]
# ### 2021년 5월 (트릭스터M 출시 - 2021년 5월 20일)

# %%
fig = plt.figure(figsize=(30, 9))

date = ncsoft_df.iloc[1474:1488]['Date']
trickster_m = ncsoft_df.iloc[1474:1488]['TricksterM']
price = ncsoft_df.iloc[1474:1488]['Close']
volume = ncsoft_df.iloc[1474:1488]['Volume']

## 일별 트릭스터M 검색량 그래프 ##
plt.subplot(2, 2, 1)
plt.plot(date, trickster_m)

# 휴장일 표시
plt.plot(ncsoft_df.iloc[1475:1477]['Date'], ncsoft_df.iloc[1475:1477]['TricksterM'], color='red')
plt.text(ncsoft_df.iloc[1479]['Date'], ncsoft_df.iloc[1479]['TricksterM'], '부처님 오신날 휴장')
plt.plot(ncsoft_df.iloc[1479]['Date'], ncsoft_df.iloc[1479]['TricksterM'], 'rX')
plt.plot(ncsoft_df.iloc[1482:1484]['Date'], ncsoft_df.iloc[1482:1484]['TricksterM'], color='red')
plt.legend(('개장','휴장'))

# 출시일 표시
plt.text(ncsoft_df.iloc[1480]['Date'], ncsoft_df.iloc[1480]['TricksterM'], '트릭스터M 출시')
plt.plot(ncsoft_df.iloc[1480]['Date'], ncsoft_df.iloc[1480]['TricksterM'], 'mX')

plt.title('트릭스터M 검색량')


## 일별 엔씨소프트 거래량 그래프 ##
plt.subplot(2, 2, 3)
plt.plot(date, volume)

# 휴장일 표시
plt.plot(ncsoft_df.iloc[1475:1477]['Date'], ncsoft_df.iloc[1475:1477]['Volume'], color='red')
plt.text(ncsoft_df.iloc[1479]['Date'], ncsoft_df.iloc[1479]['Volume'], '부처님 오신날 휴장')
plt.plot(ncsoft_df.iloc[1479]['Date'], ncsoft_df.iloc[1479]['Volume'], 'rX')
plt.plot(ncsoft_df.iloc[1479]['Date'], ncsoft_df.iloc[1479]['Volume'], color='red')
plt.plot(ncsoft_df.iloc[1482:1484]['Date'], ncsoft_df.iloc[1482:1484]['Volume'], color='red')
plt.legend(('개장','휴장'))

# 출시일 표시
plt.text(ncsoft_df.iloc[1480]['Date'], ncsoft_df.iloc[1480]['Volume'], '트릭스터M 출시')
plt.plot(ncsoft_df.iloc[1480]['Date'], ncsoft_df.iloc[1480]['Volume'], 'mX')

plt.title('엔씨소프트 거래량')
# Out:
# Text(0.5, 1.0, '엔씨소프트 거래량')
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 8 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 8 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
plt.figure(figsize=(20, 6))

date = ncsoft_df.iloc[1474:1488]['Date']
price = ncsoft_df.iloc[1474:1488]['Close']

plt.plot(date, price)

# 휴장일 표시
plt.plot(ncsoft_df.iloc[1475:1477]['Date'], ncsoft_df.iloc[1475:1477]['Close'], color='red')
plt.text(ncsoft_df.iloc[1478]['Date'], ncsoft_df.iloc[1478]['Close'], '부처님 오신날 휴장')
plt.plot(ncsoft_df.iloc[1479]['Date'], ncsoft_df.iloc[1479]['Close'], 'rX')
plt.plot(ncsoft_df.iloc[1482:1484]['Date'], ncsoft_df.iloc[1482:1484]['Close'], color='red')
plt.legend(('개장','휴장'))

# 출시일 표시
plt.text(ncsoft_df.iloc[1480]['Date'], ncsoft_df.iloc[1480]['Close'], '트릭스터M 출시')
plt.plot(ncsoft_df.iloc[1480]['Date'], ncsoft_df.iloc[1480]['Close'], 'mX')

plt.title('엔씨소프트 종가')
# Out:
# Text(0.5, 1.0, '엔씨소프트 종가')
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 8 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 8 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# ### 2021년 5월 10일
#
# ![image](https://user-images.githubusercontent.com/76269316/159708428-2c1bae4c-be82-4788-8537-9cf38c9eb231.png)
#
# <br>
#
# ### 2021년 5월 21일
# ![image](https://user-images.githubusercontent.com/76269316/159709942-73ad10b7-9548-4570-bbd1-d2bbd1950c04.png)
#
# <br>
#
# ### 2021년 8월 14일
# ![image](https://user-images.githubusercontent.com/76269316/159711672-da12ebd4-e975-4484-9963-697e41525f6b.png)

# %% [markdown]
# ### 2021년 8월 (블레이드 앤 소울2 출시 - 2021년 8월 26일)

# %%
ncsoft_df[1572:1580].describe()
# Out:
#        LineageM  Lineage2M  TricksterM  Blade & Soul2   LineageW  \
# count  8.000000   8.000000    8.000000       8.000000   8.000000
# mean   0.218909   0.558057    0.236076      32.020084   5.428166
# std    0.117956   0.218073    0.085569      33.076697   3.029305
# min    0.122050   0.340170    0.117950       5.667360   2.809110
# 25%    0.135105   0.398087    0.178903       6.713880   3.799060
# 50%    0.170415   0.486690    0.236675      21.546405   4.274845
# 75%    0.255675   0.651732    0.294117      45.383325   5.975262
# max    0.423710   0.942550    0.343490     100.000000  12.165140
#
#                Close           Open           High            Low  \
# count       8.000000       8.000000       8.000000       8.000000
# mean   794250.000000  810250.000000  817750.000000  787875.000000
# std     69774.637226   55620.525502   55409.514397   69575.113572
# min    659000.000000  686000.000000  693000.000000  650000.000000
# ...

# %%
fig = plt.figure(figsize=(30, 9))

date = ncsoft_df.iloc[1572:1586]['Date']
blade_soul2 = ncsoft_df.iloc[1572:1586]['Blade & Soul2']
price = ncsoft_df.iloc[1572:1586]['Close']
volume = ncsoft_df.iloc[1572:1586]['Volume']

## 일별 블레이드 앤 소울2 검색량 그래프 ##
plt.subplot(2, 2, 1)
plt.plot(date, blade_soul2)

# 휴장일 표시
plt.plot(ncsoft_df.iloc[1573:1575]['Date'], ncsoft_df.iloc[1573:1575]['Blade & Soul2'], color='red')
plt.plot(ncsoft_df.iloc[1580:1582]['Date'], ncsoft_df.iloc[1580:1582]['Blade & Soul2'], color='red')
plt.legend(('개장','휴장'))

# 출시일 표시
plt.text(ncsoft_df.iloc[1578]['Date'], ncsoft_df.iloc[1578]['Blade & Soul2'], '블레이드 앤 소울2 출시')
plt.plot(ncsoft_df.iloc[1578]['Date'], ncsoft_df.iloc[1578]['Blade & Soul2'], 'mX')

plt.title('블레이드 앤 소울2 검색량')


## 일별 엔씨소프트 거래량 그래프 ##
plt.subplot(2, 2, 3)
plt.plot(date, volume)

# 휴장일 표시
plt.plot(ncsoft_df.iloc[1573:1575]['Date'], ncsoft_df.iloc[1573:1575]['Volume'], color='red')
plt.plot(ncsoft_df.iloc[1580:1582]['Date'], ncsoft_df.iloc[1580:1582]['Volume'], color='red')
plt.legend(('개장','휴장'))

# 출시일 표시
plt.text(ncsoft_df.iloc[1578]['Date'], ncsoft_df.iloc[1578]['Volume'], '블레이드 앤 소울2 출시')
plt.plot(ncsoft_df.iloc[1578]['Date'], ncsoft_df.iloc[1578]['Volume'], 'mX')

plt.title('엔씨소프트 거래량')
# Out:
# Text(0.5, 1.0, '엔씨소프트 거래량')

# %%
plt.figure(figsize=(20, 6))

date = ncsoft_df.iloc[1572:1586]['Date']
price = ncsoft_df.iloc[1572:1586]['Close']

plt.plot(date, price)

# 휴장일 표시
plt.plot(ncsoft_df.iloc[1573:1575]['Date'], ncsoft_df.iloc[1573:1575]['Close'], color='red')
plt.plot(ncsoft_df.iloc[1580:1582]['Date'], ncsoft_df.iloc[1580:1582]['Close'], color='red')
plt.legend(('개장','휴장'))

# 출시일 표시
plt.text(ncsoft_df.iloc[1578]['Date'], ncsoft_df.iloc[1578]['Close'], '블레이드 앤 소울2 출시')
plt.plot(ncsoft_df.iloc[1578]['Date'], ncsoft_df.iloc[1578]['Close'], 'mX')

plt.title('엔씨소프트 종가')
# Out:
# Text(0.5, 1.0, '엔씨소프트 종가')

# %% [markdown]
# <img width="790" alt="스크린샷 2022-03-24 오전 7 11 50" src="https://user-images.githubusercontent.com/76269316/159804616-809c9e7e-c856-4c3e-91ac-ad846eb4077f.png">
#
# <br>
#
# ![image](https://user-images.githubusercontent.com/76269316/159713694-bebc1e64-008c-4fe6-aabf-a79cc457b494.png)

# %% [markdown]
# ### 2021년 11월 (리니지 W 출시 - 2021년 11월 4일, 2021년 11월 11일 - NFT 게임 출시 발표)

# %%
ncsoft_df[1642:1650].describe()
# Out:
#        LineageM  Lineage2M  TricksterM  Blade & Soul2    LineageW  \
# count  8.000000   8.000000    8.000000       8.000000    8.000000
# mean   0.473373   0.693275    0.078185       1.050687   26.198263
# std    0.220892   0.344951    0.030703       0.294505   32.319996
# min    0.249360   0.395010    0.050330       0.755640    3.708190
# 25%    0.326655   0.467160    0.059550       0.841550    4.984180
# 50%    0.378265   0.583330    0.073095       0.962905   15.614125
# 75%    0.581627   0.757755    0.083465       1.149730   30.141115
# max    0.895520   1.435990    0.146580       1.542150  100.000000
#
#                Close         Open           High            Low        Volume
# count       8.000000       8.0000       8.000000       8.000000  8.000000e+00
# mean   631000.000000  627125.0000  640000.000000  616000.000000  3.888279e+05
# std     18905.781429   15282.4596   15184.578643   23826.755669  4.556510e+05
# ...

# %%
fig = plt.figure(figsize=(30, 9))

date = ncsoft_df.iloc[1642:1655]['Date']
lineage_w = ncsoft_df.iloc[1642:1655]['LineageW']
price = ncsoft_df.iloc[1642:1655]['Close']
volume = ncsoft_df.iloc[1642:1655]['Volume']

## 일별 리니지W 검색량 그래프 ##
plt.subplot(2, 2, 1)
plt.plot(date, lineage_w)

# 휴장일 표시
plt.plot(ncsoft_df.iloc[1642:1644]['Date'], ncsoft_df.iloc[1642:1644]['LineageW'], color='red')
plt.plot(ncsoft_df.iloc[1650:1652]['Date'], ncsoft_df.iloc[1650:1652]['LineageW'], color='red')
plt.legend(('개장','휴장'))

# 출시일 표시
plt.text(ncsoft_df.iloc[1648]['Date'], ncsoft_df.iloc[1648]['LineageW'], '리니지W 출시')
plt.plot(ncsoft_df.iloc[1648]['Date'], ncsoft_df.iloc[1648]['LineageW'], 'mX')
# plt.text(ncsoft_df.iloc[1655]['Date'], ncsoft_df.iloc[1655]['LineageW'], 'NFT 게임 출시 발표')
# plt.plot(ncsoft_df.iloc[1655]['Date'], ncsoft_df.iloc[1655]['LineageW'], 'mX')

plt.title('리니지W 검색량')


## 일별 엔씨소프트 거래량 그래프 ##
plt.subplot(2, 2, 3)
plt.plot(date, volume)

# 휴장일 표시
plt.plot(ncsoft_df.iloc[1642:1644]['Date'], ncsoft_df.iloc[1642:1644]['Volume'], color='red')
plt.plot(ncsoft_df.iloc[1650:1652]['Date'], ncsoft_df.iloc[1650:1652]['Volume'], color='red')
plt.legend(('개장','휴장'))

# 출시일 표시
plt.text(ncsoft_df.iloc[1648]['Date'], ncsoft_df.iloc[1648]['Volume'], '리니지W 출시')
plt.plot(ncsoft_df.iloc[1648]['Date'], ncsoft_df.iloc[1648]['Volume'], 'mX')
# plt.text(ncsoft_df.iloc[1655]['Date'], ncsoft_df.iloc[1655]['Volume'], 'NFT 게임 출시 발표')
# plt.plot(ncsoft_df.iloc[1655]['Date'], ncsoft_df.iloc[1655]['Volume'], 'mX')

plt.title('엔씨소프트 거래량')
# Out:
# Text(0.5, 1.0, '엔씨소프트 거래량')

# %%
plt.figure(figsize=(20, 6))

date = ncsoft_df.iloc[1642:1656]['Date']
price = ncsoft_df.iloc[1642:1656]['Close']

plt.plot(date, price)

# 휴장일 표시
plt.plot(ncsoft_df.iloc[1642:1644]['Date'], ncsoft_df.iloc[1642:1644]['Close'], color='red')
plt.plot(ncsoft_df.iloc[1650:1652]['Date'], ncsoft_df.iloc[1650:1652]['Close'], color='red')
plt.legend(('개장','휴장'))

# 출시일 표시
plt.text(ncsoft_df.iloc[1648]['Date'], ncsoft_df.iloc[1648]['Close'], '리니지W 출시')
plt.plot(ncsoft_df.iloc[1648]['Date'], ncsoft_df.iloc[1648]['Close'], 'mX')
plt.text(ncsoft_df.iloc[1655]['Date'], ncsoft_df.iloc[1655]['Close'], 'NFT 게임 출시 발표')
plt.plot(ncsoft_df.iloc[1655]['Date'], ncsoft_df.iloc[1655]['Close'], 'mX')

# %%
fig = plt.figure(figsize=(70, 20))

###### 리니지M ######
date1 = ncsoft_df.iloc[45:60]['Date']
price = ncsoft_df.iloc[45:60]['Close']

plt.subplot(5, 5, 1)
plt.plot(date1, price)

# 휴장일 표시
plt.plot(ncsoft_df.iloc[47:49]['Date'], ncsoft_df.iloc[47:49]['Close'], color='red')
plt.plot(ncsoft_df.iloc[54:56]['Date'], ncsoft_df.iloc[54:56]['Close'], color='red')
plt.legend(('개장','휴장'))

# 출시일 표시
plt.text(ncsoft_df.iloc[51]['Date'], ncsoft_df.iloc[51]['Close'], '리니지M 출시')
plt.plot(ncsoft_df.iloc[51]['Date'], ncsoft_df.iloc[51]['Close'], 'mX')

plt.title('리니지M 출시에 따른 가격 변화량')


###### 리니지2M ######
date2 = ncsoft_df.iloc[934:948]['Date']
price = ncsoft_df.iloc[934:948]['Close']

plt.subplot(5, 5, 6)
plt.plot(date2, price)

# 휴장일 표시
plt.plot(ncsoft_df.iloc[936:938]['Date'], ncsoft_df.iloc[936:938]['Close'], color='red')
plt.plot(ncsoft_df.iloc[943:945]['Date'], ncsoft_df.iloc[943:945]['Close'], color='red')
plt.legend(('개장','휴장'))

# 출시일 표시
plt.text(ncsoft_df.iloc[940]['Date'], ncsoft_df.iloc[940]['Close'], '리니지2M 출시')
plt.plot(ncsoft_df.iloc[940]['Date'], ncsoft_df.iloc[940]['Close'], 'mX')

plt.title('리니지2M 출시에 따른 가격 변화량')


###### 트릭스터M ######
date3 = ncsoft_df.iloc[1474:1488]['Date']
price = ncsoft_df.iloc[1474:1488]['Close']

plt.subplot(5, 5, 11)
plt.plot(date3, price)

# 휴장일 표시
plt.plot(ncsoft_df.iloc[1475:1477]['Date'], ncsoft_df.iloc[1475:1477]['Close'], color='red')
plt.text(ncsoft_df.iloc[1478]['Date'], ncsoft_df.iloc[1478]['Close'], '부처님 오신날 휴장')
plt.plot(ncsoft_df.iloc[1479]['Date'], ncsoft_df.iloc[1479]['Close'], 'rX')
plt.plot(ncsoft_df.iloc[1482:1484]['Date'], ncsoft_df.iloc[1482:1484]['Close'], color='red')
plt.legend(('개장','휴장'))

# 출시일 표시
plt.text(ncsoft_df.iloc[1480]['Date'], ncsoft_df.iloc[1480]['Close'], '트릭스터M 출시')
plt.plot(ncsoft_df.iloc[1480]['Date'], ncsoft_df.iloc[1480]['Close'], 'mX')

plt.title('트릭스터M 출시에 따른 가격 변화량')


###### 블레이드 앤 소울2 ######
date4 = ncsoft_df.iloc[1572:1586]['Date']
price = ncsoft_df.iloc[1572:1586]['Close']

## 일별 엔씨소프트 종가 그래프 ##
plt.subplot(5, 5, 16)
plt.plot(date4, price)

# 휴장일 표시
plt.plot(ncsoft_df.iloc[1573:1575]['Date'], ncsoft_df.iloc[1573:1575]['Close'], color='red')
plt.plot(ncsoft_df.iloc[1580:1582]['Date'], ncsoft_df.iloc[1580:1582]['Close'], color='red')
plt.legend(('개장','휴장'))

# 출시일 표시
plt.text(ncsoft_df.iloc[1579]['Date'], ncsoft_df.iloc[1579]['Close'], '블레이드 앤 소울2 출시')
plt.plot(ncsoft_df.iloc[1579]['Date'], ncsoft_df.iloc[1579]['Close'], 'mX')

plt.title('블레이드 앤 소울2 출시에 따른 가격 변화량')


###### 리니지W ######
date5 = ncsoft_df.iloc[1642:1655]['Date']
price = ncsoft_df.iloc[1642:1655]['Close']

## 일별 엔씨소프트 종가 그래프 ##
plt.subplot(5, 5, 21)
plt.plot(date5, price)

# 휴장일 표시
plt.plot(ncsoft_df.iloc[1642:1644]['Date'], ncsoft_df.iloc[1642:1644]['Close'], color='red')
plt.plot(ncsoft_df.iloc[1650:1652]['Date'], ncsoft_df.iloc[1650:1652]['Close'], color='red')
plt.legend(('개장','휴장'))

# 출시일 표시
plt.text(ncsoft_df.iloc[1648]['Date'], ncsoft_df.iloc[1648]['Close'], '리니지W 출시')
plt.plot(ncsoft_df.iloc[1648]['Date'], ncsoft_df.iloc[1648]['Close'], 'mX')
# plt.text(ncsoft_df.iloc[1655]['Date'], ncsoft_df.iloc[1655]['Close'], 'NFT 게임 출시 발표')
# plt.plot(ncsoft_df.iloc[1655]['Date'], ncsoft_df.iloc[1655]['Close'], 'mX')

plt.title('리니지W 출시에 따른 가격 변화량')
# Out:
# Text(0.5, 1.0, '리니지W 출시에 따른 가격 변화량')
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 8 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 8 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# ### 리니지M 출시 후 세 달간 주가 변화 추이

# %%
fig = plt.figure(figsize=(30, 9))

date = ncsoft_df.iloc[51:144]['Date']
lineagem_price = ncsoft_df.iloc[51:144]['Close']

## 일별 블레이드 앤 소울2 검색량 그래프 ##
plt.subplot(2, 2, 1)
plt.plot(date, lineagem_price)

# 출시일 표시
plt.text(ncsoft_df.iloc[51]['Date'], ncsoft_df.iloc[51]['Close'], '리니지M 출시 (2017-06-21)')
plt.plot(ncsoft_df.iloc[51]['Date'], ncsoft_df.iloc[51]['Close'], 'mX')

# 마지막 날짜 표시
plt.text(ncsoft_df.iloc[143]['Date'], ncsoft_df.iloc[143]['Close'], '2017-09-21')
plt.plot(ncsoft_df.iloc[143]['Date'], ncsoft_df.iloc[143]['Close'], 'mX')


ax = plt.gca()
ax.axes.xaxis.set_ticks([])

plt.title('리니지M 출시 이후 세 달간 주가 변화 추이')
# Out:
# Text(0.5, 1.0, '리니지M 출시 이후 세 달간 주가 변화 추이')

# %% [markdown]
# ### 리니지2M 출시 후 세 달간 주가 변화 추이

# %%
fig = plt.figure(figsize=(30, 9))

date = ncsoft_df.iloc[942:1033]['Date']
lienage2m_price = ncsoft_df.iloc[942:1033]['Close']

## 일별 블레이드 앤 소울2 검색량 그래프 ##
plt.subplot(2, 2, 1)
plt.plot(date, lienage2m_price)

# 출시일 표시
plt.text(ncsoft_df.iloc[942]['Date'], ncsoft_df.iloc[942]['Close'], '리니지2M 출시 (2019-11-27)')
plt.plot(ncsoft_df.iloc[942]['Date'], ncsoft_df.iloc[942]['Close'], 'mX')

# 마지막 날짜 표시
plt.text(ncsoft_df.iloc[1032]['Date'], ncsoft_df.iloc[1032]['Close'], '2020-02-27')
plt.plot(ncsoft_df.iloc[1032]['Date'], ncsoft_df.iloc[1032]['Close'], 'mX')


ax = plt.gca()
ax.axes.xaxis.set_ticks([])

plt.title('리니지2M 출시 이후 세 달간 주가 변화 추이')
# Out:
# Text(0.5, 1.0, '리니지2M 출시 이후 세 달간 주가 변화 추이')

# %% [markdown]
# ### 트릭스터M 출시 후 세 달간 주가 변화 추이

# %%
fig = plt.figure(figsize=(30, 9))

date = ncsoft_df.iloc[1483:1574]['Date']
tricksterm_price = ncsoft_df.iloc[1483:1574]['Close']

## 일별 블레이드 앤 소울2 검색량 그래프 ##
plt.subplot(2, 2, 1)
plt.plot(date, tricksterm_price)

# 출시일 표시
plt.text(ncsoft_df.iloc[1483]['Date'], ncsoft_df.iloc[1483]['Close'], '트릭스터M 출시 (2021-05-20)')
plt.plot(ncsoft_df.iloc[1483]['Date'], ncsoft_df.iloc[1483]['Close'], 'mX')

# 마지막 날짜 표시
plt.text(ncsoft_df.iloc[1572]['Date'], ncsoft_df.iloc[1572]['Close'], '2021-08-20')
plt.plot(ncsoft_df.iloc[1572]['Date'], ncsoft_df.iloc[1572]['Close'], 'mX')


ax = plt.gca()
ax.axes.xaxis.set_ticks([])

plt.title('트릭스터M 출시 이후 세 달간 주가 변화 추이')
# Out:
# Text(0.5, 1.0, '트릭스터M 출시 이후 세 달간 주가 변화 추이')

# %% [markdown]
# ### 블레이드 & 소울2, 리니지 W 출시 후 주가 변화 추이

# %%
fig = plt.figure(figsize=(30, 9))

date = ncsoft_df.iloc[1580:1717]['Date']
blade_price = ncsoft_df.iloc[1580:1717]['Close']

## 일별 블레이드 앤 소울2 검색량 그래프 ##
plt.subplot(2, 2, 1)
plt.plot(date, blade_price)

# 블레이드 앤 소울2 출시일 표시
plt.text(ncsoft_df.iloc[1580]['Date'], ncsoft_df.iloc[1580]['Close'], '블레이드 & 소울2 출시 (2021-08-27)')
plt.plot(ncsoft_df.iloc[1580]['Date'], ncsoft_df.iloc[1580]['Close'], 'mX')

# 리니지W 출시일 표시
plt.text(ncsoft_df.iloc[1648]['Date'], ncsoft_df.iloc[1648]['Close'], '리니지W 출시')
plt.plot(ncsoft_df.iloc[1648]['Date'], ncsoft_df.iloc[1648]['Close'], 'mX')

# NFT 게임 출시 발표
plt.text(ncsoft_df.iloc[1655]['Date'], ncsoft_df.iloc[1655]['Close'], 'NFT 게임 출시 발표 (2021-11-11)')
plt.plot(ncsoft_df.iloc[1655]['Date'], ncsoft_df.iloc[1655]['Close'], 'mX')

# 마지막 날짜 표시
plt.text(ncsoft_df.iloc[1716]['Date'], ncsoft_df.iloc[1716]['Close'], '2022-01-11')
plt.plot(ncsoft_df.iloc[1716]['Date'], ncsoft_df.iloc[1716]['Close'], 'mX')

ax = plt.gca()
ax.axes.xaxis.set_ticks([])

plt.title('블레이드 & 소울2, 리니지W 출시 이후 주가 변화 추이')
# Out:
# Text(0.5, 1.0, '블레이드 & 소울2, 리니지W 출시 이후 주가 변화 추이')

# %% [markdown]
# ### 2021년 4분기 실적발표 (2022.02.15)
#
# <img width="934" alt="스크린샷 2022-03-23 오후 11 19 32" src="https://user-images.githubusercontent.com/76269316/159720862-6eaf9599-e3c4-4cd3-a3bb-ffdae045d132.png">

# %% [markdown]
# ### 가설1: 게임을 출시한 주에 해당 게임에 대한 검색량과 거래량은 비례할 것이다
#
# ### 가설2: 선반영으로 인해서 그 전에 이미 주가가 올랐기 때문에 출시날 주가가 하락할 것이다.
#
# ### 주식은 그 안에 얽힌 이해 관계들이 너무 많아 이런 단편적인 정보를 가지고 그 방향성을 예측하기 힘들며, <br> 제대로 된 예측을 위해선 해당 기업에 대한 도메인 지식 같은 다양한 정보가 필요하다.
