# %%
import pandas as pd
import os
import sys
import urllib.request
import json
import re

# %%
def clean_html(x):
  #https://predictor-ver1.tistory.com/4
  x = re.sub("\&\w*\;","",x)
  x = re.sub("<.*?>","",x)
  return x

# %%
client_id = "8sAydq_QSOxKcICuD2Og" #발급받은 ID 입력
client_secret = "OruQjbmaXF" #발급받은 PW 입력
encText = urllib.parse.quote("리니지") # 검색할 단어 입력
url = "https://openapi.naver.com/v1/search/news?query=" + encText # json 결과
#url = "https://openapi.naver.com/v1/search/news.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    result = response_body.decode('utf-8')
    #print(result)
else:
    print("Error Code:" + rescode)

# %%
result_json = json.loads(result)

# %%
df_json = pd.DataFrame(result_json["items"])

# %%
df_json
# Out:
#                                                title  \
# 0  [PS게임] 넷마블, '넷마블 프로야구 2022' 정식 출시...엔씨소프트, 프로야...
# 1            <b>리니지</b>W 하반기 북미·유럽 출시… TL은 연내 글로벌 론칭
# 2                               [게임 단신] 엔씨, 넷마블, 컴투스
# 3      [씨레라] ‘암호화폐’ 신사업 낙점 SK스퀘어 박정호·주식부호 눈앞 마켓컬리...
# 4                 [게임소식] KBO리그 개막 맞아 야구 게임 출시 및 업데이트
# 5                엔씨소프트, 프로야구 개막 기념 NC 다이노스 응원 이벤트 시작
# 6                           엔씨, 프로야구 개막 기념 응원 이벤트 전개
# 7  [A 게임가 소식] 넷마블, '블레이드 &amp; 소울 레볼루션' 신규 던전 업데이트 外
# 8              엔씨소프트 '脫<b>리니지</b>' 선언…청사진 내놓은 '택진이형'
# 9           김택진 &quot;엔씨소프트 최우선 목표는 글로벌 게임사 도약&quot;
#
#                                         originallink  \
# 0  http://www.psnews.co.kr/news/articleView.html?...
# 1      http://www.fnnews.com/news/202203301809250671
# 2  http://www.wolyo.co.kr/news/articleView.html?i...
# 3  https://biz.sbs.co.kr/article_hub/20000056432?...
# 4  http://sports.hankooki.com/news/articleView.ht...
# 5  http://game.dailyesports.com/view.php?ud=20220...
# 6  http://www.tgdaily.co.kr/news/articleView.html...
# 7  http://www.asiaa.co.kr/news/articleView.html?i...
# 8  https://www.hankyung.com/it/article/2022033025261
# 9          https://www.paxnetnews.com/articles/85270
#
#                                                 link  \
# 0  http://www.psnews.co.kr/news/articleView.html?...
# 1  https://news.naver.com/main/read.naver?mode=LS...
# 2  http://www.wolyo.co.kr/news/articleView.html?i...
# 3  https://news.naver.com/main/read.naver?mode=LS...
# 4  http://sports.hankooki.com/news/articleView.ht...
# 5  https://sports.news.naver.com/news.nhn?oid=347...
# 6  http://www.tgdaily.co.kr/news/articleView.html...
# 7  http://www.asiaa.co.kr/news/articleView.html?i...
# 8  https://news.naver.com/main/read.naver?mode=LS...
# 9          https://www.paxnetnews.com/articles/85270
#
#                                          description  \
# 0  엔씨가 서비스하는 ▲PC온라인 게임 4종(<b>리니지</b>, <b>리니지</b>2...
# 1  또 다른 대작 '<b>리니지</b>W'도 올 하반기 북미와 유럽 등 서구권 국가에 ...
# 2  엔씨(NC)가 서비스하는 ▲PC온라인 게임 4종(<b>리니지</b>·<b>리니지</...
# 3  박 대표가 주총에서 언급한 <b>리니지</b> 게임에서 힌트를 찾아볼 수 있을 것 ...
# 4  엔씨(NC)가 서비스하는 ▲PC온라인 게임 4종(<b>리니지</b>, <b>리니지<...
# 5  엔씨(NC)가 서비스하는 ▲PC 온라인게임 4종(<b>리니지</b>, <b>리니지<...
# 6  이번 이벤트는 <b>리니지</b>, <b>리니지</b>2, 아이온, 블레이드&amp...
# 7  엔씨가 서비스하는 △PC온라인 게임 4종(<b>리니지</b>·<b>리니지</b>2·...
# 8  김택진 엔씨소프트 대표(사진)가 23년간 회사의 주력 게임 역할을 해온 ‘<b>리니...
# 9  엔씨소프트는 현재 최대 흥행작인 모바일 MMORPG(다중접속역할수행게임) '<b>리...
#
#                            pubDate
# 0  Wed, 30 Mar 2022 18:18:00 +0900
# 1  Wed, 30 Mar 2022 18:10:00 +0900
# 2  Wed, 30 Mar 2022 18:02:00 +0900
# 3  Wed, 30 Mar 2022 18:01:00 +0900
# 4  Wed, 30 Mar 2022 17:56:00 +0900
# 5  Wed, 30 Mar 2022 17:51:00 +0900
# 6  Wed, 30 Mar 2022 17:50:00 +0900
# 7  Wed, 30 Mar 2022 17:40:00 +0900
# 8  Wed, 30 Mar 2022 17:38:00 +0900
# 9  Wed, 30 Mar 2022 17:36:00 +0900

# %%
df_json['title'] = df_json['title'].apply(lambda x: clean_html(x))
df_json['description'] = df_json['description'].apply(lambda x: clean_html(x))

# %%
df_json
# Out:
#                                                title  \
# 0  [PS게임] 넷마블, '넷마블 프로야구 2022' 정식 출시...엔씨소프트, 프로야...
# 1                   리니지W 하반기 북미·유럽 출시… TL은 연내 글로벌 론칭
# 2                               [게임 단신] 엔씨, 넷마블, 컴투스
# 3      [씨레라] ‘암호화폐’ 신사업 낙점 SK스퀘어 박정호·주식부호 눈앞 마켓컬리...
# 4                 [게임소식] KBO리그 개막 맞아 야구 게임 출시 및 업데이트
# 5                엔씨소프트, 프로야구 개막 기념 NC 다이노스 응원 이벤트 시작
# 6                           엔씨, 프로야구 개막 기념 응원 이벤트 전개
# 7       [A 게임가 소식] 넷마블, '블레이드  소울 레볼루션' 신규 던전 업데이트 外
# 8                     엔씨소프트 '脫리니지' 선언…청사진 내놓은 '택진이형'
# 9                       김택진 엔씨소프트 최우선 목표는 글로벌 게임사 도약
